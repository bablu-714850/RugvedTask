# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
pd.read_csv?
# Out:
# Signature:
# pd.read_csv(
#     filepath_or_buffer: 'FilePath | ReadCsvBuffer[bytes] | ReadCsvBuffer[str]',
#     *,
#     sep: 'str | None | lib.NoDefault' = <no_default>,
#     delimiter: 'str | None | lib.NoDefault' = None,
#     header: "int | Sequence[int] | None | Literal['infer']" = 'infer',
#     names: 'Sequence[Hashable] | None | lib.NoDefault' = <no_default>,
#     index_col: 'IndexLabel | Literal[False] | None' = None,
#     usecols: 'UsecolsArgType' = None,
#     dtype: 'DtypeArg | None' = None,
#     engine: 'CSVEngine | None' = None,
#     converters: 'Mapping[Hashable, Callable] | None' = None,
#     true_values: 'list | None' = None,
#     false_values: 'list | None' = None,
#     skipinitialspace: 'bool' = False,
#     skiprows: 'list[int] | int | Callable[[Hashable], bool] | None' = None,
#     skipfooter: 'int' = 0,
#     nrows: 'int | None' = None,
#     na_values: 'Hashable | Iterable[Hashable] | Mapping[Hashable, Iterable[Hashable]] | None' = None,
# ...

# %%
df=pd.read_csv('matches.csv')

# %%
df
# Out:
#         id  season           city        date                        team1  \
# 0        1    2017      Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1        2    2017           Pune  2017-04-06               Mumbai Indians
# 2        3    2017         Rajkot  2017-04-07                Gujarat Lions
# 3        4    2017         Indore  2017-04-08       Rising Pune Supergiant
# 4        5    2017      Bangalore  2017-04-08  Royal Challengers Bangalore
# ..     ...     ...            ...         ...                          ...
# 751  11347    2019         Mumbai    05/05/19        Kolkata Knight Riders
# 752  11412    2019        Chennai    07/05/19          Chennai Super Kings
# 753  11413    2019  Visakhapatnam    08/05/19          Sunrisers Hyderabad
# 754  11414    2019  Visakhapatnam    10/05/19               Delhi Capitals
# 755  11415    2019      Hyderabad    12/05/19               Mumbai Indians
#
# ...

# %%
df.head()
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
matches=df[df['season']==2008]
matches
# Out:
#       id  season        city        date                        team1  \
# 59    60    2008   Bangalore  2008-04-18        Kolkata Knight Riders
# 60    61    2008  Chandigarh  2008-04-19          Chennai Super Kings
# 61    62    2008       Delhi  2008-04-19             Rajasthan Royals
# 62    63    2008      Mumbai  2008-04-20               Mumbai Indians
# 63    64    2008     Kolkata  2008-04-20              Deccan Chargers
# 64    65    2008      Jaipur  2008-04-21              Kings XI Punjab
# 65    66    2008   Hyderabad  2008-04-22              Deccan Chargers
# 66    67    2008     Chennai  2008-04-23          Chennai Super Kings
# 67    68    2008   Hyderabad  2008-04-24              Deccan Chargers
# 68    69    2008  Chandigarh  2008-04-25              Kings XI Punjab
# 69    70    2008   Bangalore  2008-04-26  Royal Challengers Bangalore
# 70    71    2008     Chennai  2008-04-26        Kolkata Knight Riders
# ...

# %%
matches.shape[0]
# Out:
# 58

# %%
match_count=df['city'].value_counts()

# %%
match_count
# Out:
# city
# Mumbai            101
# Kolkata            77
# Delhi              74
# Bangalore          66
# Hyderabad          64
# Chennai            57
# Jaipur             47
# Chandigarh         46
# Pune               38
# Durban             15
# Bengaluru          14
# Visakhapatnam      13
# Centurion          12
# Ahmedabad          12
# Rajkot             10
# Mohali             10
# Indore              9
# Dharamsala          9
# Johannesburg        8
# Cuttack             7
# Ranchi              7
# Port Elizabeth      7
# Cape Town           7
# Abu Dhabi           7
# Sharjah             6
# Raipur              6
# Kochi               5
# Kanpur              4
# Nagpur              3
# Kimberley           3
# East London         3
# Bloemfontein        2
# Name: count, dtype: int64

# %% [markdown]
# max_city=match_count.idmax()

# %%
max_city=match_count.idxmax()
max_city
# Out:
# 'Mumbai'

# %%
min_city=match_count.idxmin()
min_city
# Out:
# 'Bloemfontein'

# %%
total_count=match_count
total_count
# Out:
# city
# Mumbai            101
# Kolkata            77
# Delhi              74
# Bangalore          66
# Hyderabad          64
# Chennai            57
# Jaipur             47
# Chandigarh         46
# Pune               38
# Durban             15
# Bengaluru          14
# Visakhapatnam      13
# Centurion          12
# Ahmedabad          12
# Rajkot             10
# Mohali             10
# Indore              9
# Dharamsala          9
# Johannesburg        8
# Cuttack             7
# Ranchi              7
# Port Elizabeth      7
# Cape Town           7
# Abu Dhabi           7
# Sharjah             6
# Raipur              6
# Kochi               5
# Kanpur              4
# Nagpur              3
# Kimberley           3
# East London         3
# Bloemfontein        2
# Name: count, dtype: int64

# %%
toss_count=df['toss_winner'].value_counts()

# %%
toss_count
# Out:
# toss_winner
# Mumbai Indians                 98
# Kolkata Knight Riders          92
# Chennai Super Kings            89
# Royal Challengers Bangalore    81
# Kings XI Punjab                81
# Delhi Daredevils               80
# Rajasthan Royals               80
# Sunrisers Hyderabad            46
# Deccan Chargers                43
# Pune Warriors                  20
# Gujarat Lions                  15
# Delhi Capitals                 10
# Kochi Tuskers Kerala            8
# Rising Pune Supergiants         7
# Rising Pune Supergiant          6
# Name: count, dtype: int64

# %%
max_toss=toss_count.idxmax()
max_toss
# Out:
# 'Mumbai Indians'

# %%
min_toss=toss_count.idxmin()
min_toss
# Out:
# 'Rising Pune Supergiant'

# %%
bat=df[df['toss_decision']=='bat']

# %%
bat
# Out:
#         id  season       city        date                        team1  \
# 4        5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# 7        8    2017     Indore  2017-04-10  Royal Challengers Bangalore
# 14      15    2017      Delhi  2017-04-15             Delhi Daredevils
# 17      18    2017      Delhi  2017-04-17             Delhi Daredevils
# 20      21    2017  Hyderabad  2017-04-19          Sunrisers Hyderabad
# ..     ...     ...        ...         ...                          ...
# 741  11337    2019      Delhi    28/04/19               Delhi Capitals
# 746  11342    2019     Mumbai    02/05/19               Mumbai Indians
# 748  11344    2019      Delhi    04/05/19             Rajasthan Royals
# 752  11412    2019    Chennai    07/05/19          Chennai Super Kings
# 755  11415    2019  Hyderabad    12/05/19               Mumbai Indians
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
bowl=df[df['toss_decision']=='field']
bowl
# Out:
#         id  season           city        date                   team1  \
# 0        1    2017      Hyderabad  2017-04-05     Sunrisers Hyderabad
# 1        2    2017           Pune  2017-04-06          Mumbai Indians
# 2        3    2017         Rajkot  2017-04-07           Gujarat Lions
# 3        4    2017         Indore  2017-04-08  Rising Pune Supergiant
# 5        6    2017      Hyderabad  2017-04-09           Gujarat Lions
# ..     ...     ...            ...         ...                     ...
# 749  11345    2019      Bengaluru    04/05/19     Sunrisers Hyderabad
# 750  11346    2019         Mohali    05/05/19     Chennai Super Kings
# 751  11347    2019         Mumbai    05/05/19   Kolkata Knight Riders
# 753  11413    2019  Visakhapatnam    08/05/19     Sunrisers Hyderabad
# 754  11414    2019  Visakhapatnam    10/05/19          Delhi Capitals
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
count=df['result'].value_counts()
count
# Out:
# result
# normal       743
# tie            9
# no result      4
# Name: count, dtype: int64

# %%
tie=df[df['result']=='tie'][['team1','team2']]
tie
# Out:
#                            team1                        team2
# 33                 Gujarat Lions               Mumbai Indians
# 125             Rajasthan Royals        Kolkata Knight Riders
# 189              Kings XI Punjab          Chennai Super Kings
# 387  Royal Challengers Bangalore          Sunrisers Hyderabad
# 400             Delhi Daredevils  Royal Challengers Bangalore
# 475             Rajasthan Royals        Kolkata Knight Riders
# 535             Rajasthan Royals              Kings XI Punjab
# 705        Kolkata Knight Riders               Delhi Capitals
# 746               Mumbai Indians          Sunrisers Hyderabad

# %%
runs=df[df['win_by_runs']>0]
max=runs.groupby('winner')['win_by_runs'].max()
max
# Out:
# winner
# Chennai Super Kings             97
# Deccan Chargers                 82
# Delhi Capitals                  39
# Delhi Daredevils                97
# Gujarat Lions                    1
# Kings XI Punjab                111
# Kochi Tuskers Kerala            17
# Kolkata Knight Riders          140
# Mumbai Indians                 146
# Pune Warriors                   38
# Rajasthan Royals               105
# Rising Pune Supergiant          61
# Rising Pune Supergiants         34
# Royal Challengers Bangalore    144
# Sunrisers Hyderabad            118
# Name: win_by_runs, dtype: int64

# %%
team=max.idxmax()
team
# Out:
# 'Mumbai Indians'

# %%
team=max.idxmin()
team
# Out:
# 'Gujarat Lions'

# %%
runs
# Out:
#         id  season       city        date                        team1  \
# 0        1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 4        5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# 8        9    2017       Pune  2017-04-11             Delhi Daredevils
# 13      14    2017    Kolkata  2017-04-15        Kolkata Knight Riders
# 14      15    2017      Delhi  2017-04-15             Delhi Daredevils
# ..     ...     ...        ...         ...                          ...
# 741  11337    2019      Delhi    28/04/19               Delhi Capitals
# 742  11338    2019    Kolkata    28/04/19        Kolkata Knight Riders
# 743  11339    2019  Hyderabad    29/04/19          Sunrisers Hyderabad
# 745  11341    2019    Chennai    01/05/19          Chennai Super Kings
# 755  11415    2019  Hyderabad    12/05/19               Mumbai Indians
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
player=df['player_of_match'].value_counts()

# %%
player[player>3]
# Out:
# player_of_match
# CH Gayle          21
# AB de Villiers    20
# RG Sharma         17
# MS Dhoni          17
# DA Warner         17
#                   ..
# SK Warne           4
# CA Lynn            4
# SS Iyer            4
# ML Hayden          4
# KH Pandya          4
# Name: count, Length: 65, dtype: int64

# %%
player.idxmax()
# Out:
# 'CH Gayle'

# %%
runs=df[df['win_by_runs']>0]
venue=runs.groupby('venue')['win_by_runs'].max()
venue
# Out:
# venue
# Barabati Stadium                                         44
# Brabourne Stadium                                        63
# Buffalo Park                                             78
# De Beers Diamond Oval                                    53
# Dr DY Patil Sports Academy                               41
# Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium      85
# Dubai International Cricket Stadium                      15
# Eden Gardens                                            102
# Feroz Shah Kotla                                        146
# Feroz Shah Kotla Ground                                  40
# Himachal Pradesh Cricket Association Stadium            111
# Holkar Cricket Stadium                                   31
# IS Bindra Stadium                                        14
# JSCA International Stadium Complex                       34
# Kingsmead                                                78
# M Chinnaswamy Stadium                                   144
# ...

# %%
venue.idxmax()
# Out:
# 'Feroz Shah Kotla'

# %%
venue.idxmin()
# Out:
# 'Vidarbha Cricket Association Stadium, Jamtha'

# %%
umpire=df['umpire1'].value_counts()
umpire
# Out:
# umpire1
# HDPK Dharmasena    73
# Asad Rauf          51
# S Ravi             49
# AK Chaudhary       43
# Aleem Dar          38
#                    ..
# Nanda Kishore       1
# SJA Taufel          1
# A Nanda Kishore     1
# SL Shastri          1
# Sundaram Ravi       1
# Name: count, Length: 61, dtype: int64

# %%
umpire.idxmax()
# Out:
# 'HDPK Dharmasena'

# %%
matches=df[df['season']==2008]
matches
# Out:
#       id  season        city        date                        team1  \
# 59    60    2008   Bangalore  2008-04-18        Kolkata Knight Riders
# 60    61    2008  Chandigarh  2008-04-19          Chennai Super Kings
# 61    62    2008       Delhi  2008-04-19             Rajasthan Royals
# 62    63    2008      Mumbai  2008-04-20               Mumbai Indians
# 63    64    2008     Kolkata  2008-04-20              Deccan Chargers
# 64    65    2008      Jaipur  2008-04-21              Kings XI Punjab
# 65    66    2008   Hyderabad  2008-04-22              Deccan Chargers
# 66    67    2008     Chennai  2008-04-23          Chennai Super Kings
# 67    68    2008   Hyderabad  2008-04-24              Deccan Chargers
# 68    69    2008  Chandigarh  2008-04-25              Kings XI Punjab
# 69    70    2008   Bangalore  2008-04-26  Royal Challengers Bangalore
# 70    71    2008     Chennai  2008-04-26        Kolkata Knight Riders
# ...

# %%
matches1=df[df['season']==2009]
matches1
# Out:
#       id  season            city        date                        team1  \
# 117  118    2009       Cape Town  2009-04-18               Mumbai Indians
# 118  119    2009       Cape Town  2009-04-18  Royal Challengers Bangalore
# 119  120    2009       Cape Town  2009-04-19              Kings XI Punjab
# 120  121    2009       Cape Town  2009-04-19        Kolkata Knight Riders
# 121  122    2009  Port Elizabeth  2009-04-20          Chennai Super Kings
# 122  123    2009          Durban  2009-04-21              Kings XI Punjab
# 123  124    2009       Cape Town  2009-04-22              Deccan Chargers
# 124  125    2009          Durban  2009-04-23             Delhi Daredevils
# 125  126    2009       Cape Town  2009-04-23             Rajasthan Royals
# 126  127    2009          Durban  2009-04-24  Royal Challengers Bangalore
# 127  128    2009          Durban  2009-04-25              Deccan Chargers
# 128  129    2009  Port Elizabeth  2009-04-26  Royal Challengers Bangalore
# ...

# %%
matches2=df[df['season']==2010]
matches2
# Out:
#       id  season        city        date                        team1  \
# 174  175    2010      Mumbai  2010-03-12        Kolkata Knight Riders
# 175  176    2010      Mumbai  2010-03-13               Mumbai Indians
# 176  177    2010  Chandigarh  2010-03-13              Kings XI Punjab
# 177  178    2010     Kolkata  2010-03-14  Royal Challengers Bangalore
# 178  179    2010     Chennai  2010-03-14              Deccan Chargers
# 179  180    2010   Ahmedabad  2010-03-15             Rajasthan Royals
# 180  181    2010   Bangalore  2010-03-16              Kings XI Punjab
# 181  182    2010     Kolkata  2010-03-16          Chennai Super Kings
# 182  183    2010       Delhi  2010-03-17               Mumbai Indians
# 183  184    2010   Bangalore  2010-03-18             Rajasthan Royals
# 184  185    2010       Delhi  2010-03-19             Delhi Daredevils
# 185  186    2010     Cuttack  2010-03-19              Deccan Chargers
# ...

# %%
matches3=df[df['season']==2011]
matches3
# Out:
#       id  season       city        date                        team1  \
# 234  235    2011    Chennai  2011-04-08          Chennai Super Kings
# 235  236    2011  Hyderabad  2011-04-09              Deccan Chargers
# 236  237    2011      Kochi  2011-04-09         Kochi Tuskers Kerala
# 237  238    2011      Delhi  2011-04-10             Delhi Daredevils
# 238  239    2011     Mumbai  2011-04-10              Kings XI Punjab
# ..   ...     ...        ...         ...                          ...
# 302  303    2011    Kolkata  2011-05-22        Kolkata Knight Riders
# 303  304    2011     Mumbai  2011-05-24  Royal Challengers Bangalore
# 304  305    2011     Mumbai  2011-05-25        Kolkata Knight Riders
# 305  306    2011    Chennai  2011-05-27  Royal Challengers Bangalore
# 306  307    2011    Chennai  2011-05-28          Chennai Super Kings
#
#                            team2           toss_winner toss_decision  result  \
# ...

# %%
matches4=df[df['season']==2012]
matches4
# Out:
#       id  season       city        date                        team1  \
# 307  308    2012    Chennai  2012-04-04          Chennai Super Kings
# 308  309    2012    Kolkata  2012-04-05        Kolkata Knight Riders
# 309  310    2012     Mumbai  2012-04-06                Pune Warriors
# 310  311    2012     Jaipur  2012-04-06             Rajasthan Royals
# 311  312    2012  Bangalore  2012-04-07  Royal Challengers Bangalore
# ..   ...     ...        ...         ...                          ...
# 376  377    2012     Jaipur  2012-05-20             Rajasthan Royals
# 377  378    2012       Pune  2012-05-22        Kolkata Knight Riders
# 378  379    2012  Bangalore  2012-05-23          Chennai Super Kings
# 379  380    2012    Chennai  2012-05-25          Chennai Super Kings
# 380  381    2012    Chennai  2012-05-27          Chennai Super Kings
#
#                      team2            toss_winner toss_decision  result  \
# ...

# %%
matches5=df[df['season']==2013]
matches5
# Out:
#       id  season       city        date                        team1  \
# 381  382    2013    Kolkata  2013-04-03             Delhi Daredevils
# 382  383    2013  Bangalore  2013-04-04  Royal Challengers Bangalore
# 383  384    2013  Hyderabad  2013-04-05          Sunrisers Hyderabad
# 384  385    2013      Delhi  2013-04-06             Rajasthan Royals
# 385  386    2013    Chennai  2013-04-06               Mumbai Indians
# ..   ...     ...        ...         ...                          ...
# 452  453    2013  Hyderabad  2013-05-19        Kolkata Knight Riders
# 453  454    2013      Delhi  2013-05-21          Chennai Super Kings
# 454  455    2013      Delhi  2013-05-22          Sunrisers Hyderabad
# 455  456    2013    Kolkata  2013-05-24             Rajasthan Royals
# 456  457    2013    Kolkata  2013-05-26               Mumbai Indians
#
#                      team2            toss_winner toss_decision  result  \
# ...

# %%
matches6=df[df['season']==2014]
matches6
# Out:
#       id  season        city        date                        team1  \
# 457  458    2014   Abu Dhabi  2014-04-16        Kolkata Knight Riders
# 458  459    2014     Sharjah  2014-04-17             Delhi Daredevils
# 459  460    2014   Abu Dhabi  2014-04-18          Chennai Super Kings
# 460  461    2014   Abu Dhabi  2014-04-18          Sunrisers Hyderabad
# 461  462    2014         NaN  2014-04-19               Mumbai Indians
# 462  463    2014         NaN  2014-04-19        Kolkata Knight Riders
# 463  464    2014     Sharjah  2014-04-20             Rajasthan Royals
# 464  465    2014   Abu Dhabi  2014-04-21          Chennai Super Kings
# 465  466    2014     Sharjah  2014-04-22              Kings XI Punjab
# 466  467    2014         NaN  2014-04-23          Chennai Super Kings
# 467  468    2014     Sharjah  2014-04-24        Kolkata Knight Riders
# 468  469    2014         NaN  2014-04-25          Sunrisers Hyderabad
# ...

# %%
matches7=df[df['season']==2015]
matches7
# Out:
#       id  season           city        date                        team1  \
# 517  518    2015        Kolkata  2015-04-08               Mumbai Indians
# 518  519    2015        Chennai  2015-04-09          Chennai Super Kings
# 519  520    2015           Pune  2015-04-10             Rajasthan Royals
# 520  521    2015        Chennai  2015-04-11          Chennai Super Kings
# 521  522    2015        Kolkata  2015-04-11        Kolkata Knight Riders
# 522  523    2015          Delhi  2015-04-12             Delhi Daredevils
# 523  524    2015         Mumbai  2015-04-12              Kings XI Punjab
# 524  525    2015      Bangalore  2015-04-13  Royal Challengers Bangalore
# 525  526    2015      Ahmedabad  2015-04-14               Mumbai Indians
# 526  527    2015        Kolkata  2015-04-30          Chennai Super Kings
# 527  528    2015           Pune  2015-04-15              Kings XI Punjab
# 528  529    2015  Visakhapatnam  2015-04-16          Sunrisers Hyderabad
# ...

# %%
matches8=df[df['season']==2016]
matches8
# Out:
#       id  season           city        date                        team1  \
# 576  577    2016         Mumbai  2016-04-09               Mumbai Indians
# 577  578    2016        Kolkata  2016-04-10             Delhi Daredevils
# 578  579    2016     Chandigarh  2016-04-11              Kings XI Punjab
# 579  580    2016      Bangalore  2016-04-12  Royal Challengers Bangalore
# 580  581    2016        Kolkata  2016-04-13        Kolkata Knight Riders
# 581  582    2016         Rajkot  2016-04-14      Rising Pune Supergiants
# 582  583    2016          Delhi  2016-04-15              Kings XI Punjab
# 583  584    2016      Hyderabad  2016-04-16          Sunrisers Hyderabad
# 584  585    2016         Mumbai  2016-04-16               Mumbai Indians
# 585  586    2016     Chandigarh  2016-04-17      Rising Pune Supergiants
# 586  587    2016      Bangalore  2016-04-17  Royal Challengers Bangalore
# 587  588    2016      Hyderabad  2016-04-18               Mumbai Indians
# ...

# %%
matches9=df[df['season']==2017]
matches9
# Out:
#     id  season        city        date                        team1  \
# 0    1    2017   Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1    2    2017        Pune  2017-04-06               Mumbai Indians
# 2    3    2017      Rajkot  2017-04-07                Gujarat Lions
# 3    4    2017      Indore  2017-04-08       Rising Pune Supergiant
# 4    5    2017   Bangalore  2017-04-08  Royal Challengers Bangalore
# 5    6    2017   Hyderabad  2017-04-09                Gujarat Lions
# 6    7    2017      Mumbai  2017-04-09        Kolkata Knight Riders
# 7    8    2017      Indore  2017-04-10  Royal Challengers Bangalore
# 8    9    2017        Pune  2017-04-11             Delhi Daredevils
# 9   10    2017      Mumbai  2017-04-12          Sunrisers Hyderabad
# 10  11    2017     Kolkata  2017-04-13              Kings XI Punjab
# 11  12    2017   Bangalore  2017-04-14  Royal Challengers Bangalore
# 12  13    2017      Rajkot  2017-04-14       Rising Pune Supergiant
# ...

# %%
matches10=df[df['season']==2018]
matches10
# Out:
#        id  season       city      date                        team1  \
# 636  7894    2018     Mumbai  07/04/18               Mumbai Indians
# 637  7895    2018     Mohali  08/04/18             Delhi Daredevils
# 638  7896    2018    Kolkata  08/04/18  Royal Challengers Bangalore
# 639  7897    2018  Hyderabad  09/04/18             Rajasthan Royals
# 640  7898    2018    Chennai  10/04/18        Kolkata Knight Riders
# 641  7899    2018     Jaipur  11/04/18             Rajasthan Royals
# 642  7900    2018  Hyderabad  12/04/18               Mumbai Indians
# 643  7901    2018  Bengaluru  13/04/18              Kings XI Punjab
# 644  7902    2018     Mumbai  14/04/18               Mumbai Indians
# 645  7903    2018    Kolkata  14/04/18        Kolkata Knight Riders
# 646  7904    2018  Bengaluru  15/04/18             Rajasthan Royals
# 647  7905    2018     Mohali  15/04/18              Kings XI Punjab
# 648  7906    2018    Kolkata  16/04/18        Kolkata Knight Riders
# ...

# %%
matches11=df[df['season']==2019]
matches11
# Out:
#         id  season           city      date                        team1  \
# 696  11137    2019        Chennai  23/03/19  Royal Challengers Bangalore
# 697  11138    2019        Kolkata  24/03/19          Sunrisers Hyderabad
# 698  11139    2019         Mumbai  24/03/19               Delhi Capitals
# 699  11140    2019         Jaipur  25/03/19              Kings XI Punjab
# 700  11141    2019          Delhi  26/03/19               Delhi Capitals
# 701  11142    2019        Kolkata  27/03/19        Kolkata Knight Riders
# 702  11143    2019      Bengaluru  28/03/19               Mumbai Indians
# 703  11144    2019      Hyderabad  29/03/19             Rajasthan Royals
# 704  11145    2019         Mohali  30/03/19               Mumbai Indians
# 705  11146    2019          Delhi  30/03/19        Kolkata Knight Riders
# 706  11147    2019      Hyderabad  31/03/19          Sunrisers Hyderabad
# 707  11148    2019        Chennai  31/03/19          Chennai Super Kings
# ...

# %%
df
# Out:
#         id  season           city        date                        team1  \
# 0        1    2017      Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1        2    2017           Pune  2017-04-06               Mumbai Indians
# 2        3    2017         Rajkot  2017-04-07                Gujarat Lions
# 3        4    2017         Indore  2017-04-08       Rising Pune Supergiant
# 4        5    2017      Bangalore  2017-04-08  Royal Challengers Bangalore
# ..     ...     ...            ...         ...                          ...
# 751  11347    2019         Mumbai    05/05/19        Kolkata Knight Riders
# 752  11412    2019        Chennai    07/05/19          Chennai Super Kings
# 753  11413    2019  Visakhapatnam    08/05/19          Sunrisers Hyderabad
# 754  11414    2019  Visakhapatnam    10/05/19               Delhi Capitals
# 755  11415    2019      Hyderabad    12/05/19               Mumbai Indians
#
# ...

# %%
toss=df['toss_winner'].value_counts()
toss
# Out:
# toss_winner
# Mumbai Indians                 98
# Kolkata Knight Riders          92
# Chennai Super Kings            89
# Royal Challengers Bangalore    81
# Kings XI Punjab                81
# Delhi Daredevils               80
# Rajasthan Royals               80
# Sunrisers Hyderabad            46
# Deccan Chargers                43
# Pune Warriors                  20
# Gujarat Lions                  15
# Delhi Capitals                 10
# Kochi Tuskers Kerala            8
# Rising Pune Supergiants         7
# Rising Pune Supergiant          6
# Name: count, dtype: int64

# %%
 toss_decision_season=df.groupby(['season','toss_decision']).size().unstack()
 toss_decision_season.plot(kind='bar',stacked=False ,figsize=(10,6),color=['skyblue','lightgreen'])
plt.title('toss decision across all seasons')
plt.xlabel('season')
plt.ylabel('count')
plt.xticks(rotation=45)
plt.legend(title='toss decision')
plt.show()

# %%
toss_decision_season=df.groupby(['season','toss_decision']).size().unstack()
toss_decision_season
# Out:
# toss_decision  bat  field
# season
# 2008            26     32
# 2009            35     22
# 2010            39     21
# 2011            25     48
# 2012            37     37
# 2013            45     31
# 2014            19     41
# 2015            25     34
# 2016            11     49
# 2017            11     48
# 2018            10     50
# 2019            10     50

# %%
toss_decision_season.plot(kind='bar',stacked=False ,figsize=(10,6),color=['skyblue','lightgreen'])
# Out:
# <Axes: xlabel='season'>

# %%
decision=df.groupby(['season','toss_decision']).size().unstack()
decision
# Out:
# toss_decision  bat  field
# season
# 2008            26     32
# 2009            35     22
# 2010            39     21
# 2011            25     48
# 2012            37     37
# 2013            45     31
# 2014            19     41
# 2015            25     34
# 2016            11     49
# 2017            11     48
# 2018            10     50
# 2019            10     50

# %%
decision.plot(kind='bar' , stacked=False , color=['skyblue','lightgreen'],figsize=(10,6))
plt.show()

# %%
df
# Out:
#         id  season           city        date                        team1  \
# 0        1    2017      Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1        2    2017           Pune  2017-04-06               Mumbai Indians
# 2        3    2017         Rajkot  2017-04-07                Gujarat Lions
# 3        4    2017         Indore  2017-04-08       Rising Pune Supergiant
# 4        5    2017      Bangalore  2017-04-08  Royal Challengers Bangalore
# ..     ...     ...            ...         ...                          ...
# 751  11347    2019         Mumbai    05/05/19        Kolkata Knight Riders
# 752  11412    2019        Chennai    07/05/19          Chennai Super Kings
# 753  11413    2019  Visakhapatnam    08/05/19          Sunrisers Hyderabad
# 754  11414    2019  Visakhapatnam    10/05/19               Delhi Capitals
# 755  11415    2019      Hyderabad    12/05/19               Mumbai Indians
#
# ...

# %%
dismissal_count=df.groupby(['win_by_wickets','winner']).size().unstack()
dismissal_count
# Out:
# winner          Chennai Super Kings  Deccan Chargers  Delhi Capitals  \
# win_by_wickets
# 0                              52.0             18.0             4.0
# 1                               1.0              NaN             NaN
# 2                               1.0              NaN             1.0
# 3                               1.0              NaN             NaN
# 4                               6.0              NaN             1.0
# 5                              12.0              2.0             2.0
# 6                               7.0              5.0             1.0
# 7                               9.0              2.0             1.0
# 8                               6.0              1.0             NaN
# 9                               4.0              NaN             NaN
# 10                              1.0              1.0             NaN
#
# winner          Delhi Daredevils  Gujarat Lions  Kings XI Punjab  \
# win_by_wickets
# ...

# %%
dismissal_count.plot(kind='bar',figsize=(15,13),color=['skyblue','lightgreen','blue','cyan','black','magenta','red','yellow','bisque','slategrey'],stacked=False)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
player=df['player_of_match'].value_counts()
player
# Out:
# player_of_match
# CH Gayle          21
# AB de Villiers    20
# RG Sharma         17
# MS Dhoni          17
# DA Warner         17
#                   ..
# PD Collingwood     1
# NV Ojha            1
# AC Voges           1
# J Theron           1
# S Hetmyer          1
# Name: count, Length: 226, dtype: int64

# %%
player.plot(kind='bar' , stacked=False , figsize=(60,30),color=['skyblue','lightgreen','blue','cyan','black','magenta','red','yellow','bisque','slategrey','lightblue','lightyellow'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
played=df['team1'].value_counts()
played
played1=df['team2'].value_counts()
played1
played3=played.add(played1)
played3
# Out:
# Chennai Super Kings            164
# Deccan Chargers                 75
# Delhi Capitals                  16
# Delhi Daredevils               161
# Gujarat Lions                   30
# Kings XI Punjab                176
# Kochi Tuskers Kerala            14
# Kolkata Knight Riders          178
# Mumbai Indians                 187
# Pune Warriors                   46
# Rajasthan Royals               147
# Rising Pune Supergiant          16
# Rising Pune Supergiants         14
# Royal Challengers Bangalore    180
# Sunrisers Hyderabad            108
# Name: count, dtype: int64

# %%
winner=df['winner'].value_counts()
winner
# Out:
# winner
# Mumbai Indians                 109
# Chennai Super Kings            100
# Kolkata Knight Riders           92
# Royal Challengers Bangalore     84
# Kings XI Punjab                 82
# Rajasthan Royals                75
# Delhi Daredevils                67
# Sunrisers Hyderabad             58
# Deccan Chargers                 29
# Gujarat Lions                   13
# Pune Warriors                   12
# Rising Pune Supergiant          10
# Delhi Capitals                  10
# Kochi Tuskers Kerala             6
# Rising Pune Supergiants          5
# Name: count, dtype: int64

# %%
df1=pd.DataFrame({'total played':[187,164,178,180,176,147,161,108,75,30,46,16,16,14,14],
                  'total wins':[109,100,92,84,82,75,67,58,29,13,12,10,10,6,5]})
df1
# Out:
#     total played  total wins
# 0            187         109
# 1            164         100
# 2            178          92
# 3            180          84
# 4            176          82
# 5            147          75
# 6            161          67
# 7            108          58
# 8             75          29
# 9             30          13
# 10            46          12
# 11            16          10
# 12            16          10
# 13            14           6
# 14            14           5

# %%
df1.index= ['Mumbai Indians',                 
            'Chennai Super Kings',          
             'Kolkata Knight Riders',           
             'Royal Challengers Bangalore',     
'             Kings XI Punjab',                 
             'Rajasthan Royals',              
              'Delhi Daredevils',              
             'Sunrisers Hyderabad',         
               'Deccan Chargers',                
             'Gujarat Lions',                   
             'Pune Warriors',               
            'Rising Pune Supergiant',          
             'Delhi Capitals',                
            'Kochi Tuskers Kerala',             
           'Rising Pune Supergiants',
           ]

# %%
df1
# Out:
#                               total played  total wins
# Mumbai Indians                         187         109
# Chennai Super Kings                    164         100
# Kolkata Knight Riders                  178          92
# Royal Challengers Bangalore            180          84
#              Kings XI Punjab           176          82
# Rajasthan Royals                       147          75
# Delhi Daredevils                       161          67
# Sunrisers Hyderabad                    108          58
# Deccan Chargers                         75          29
# Gujarat Lions                           30          13
# Pune Warriors                           46          12
# Rising Pune Supergiant                  16          10
# Delhi Capitals                          16          10
# Kochi Tuskers Kerala                    14           6
# Rising Pune Supergiants                 14           5

# %%
win_rate=df1['total wins']/df1['total played']*100
win_rate
# Out:
# Mumbai Indians                  58.288770
# Chennai Super Kings             60.975610
# Kolkata Knight Riders           51.685393
# Royal Challengers Bangalore     46.666667
#              Kings XI Punjab    46.590909
# Rajasthan Royals                51.020408
# Delhi Daredevils                41.614907
# Sunrisers Hyderabad             53.703704
# Deccan Chargers                 38.666667
# Gujarat Lions                   43.333333
# Pune Warriors                   26.086957
# Rising Pune Supergiant          62.500000
# Delhi Capitals                  62.500000
# Kochi Tuskers Kerala            42.857143
# Rising Pune Supergiants         35.714286
# dtype: float64

# %%
df1['win rate']=win_rate

# %%
df1
# Out:
#                               total played  total wins   win rate
# Mumbai Indians                         187         109  58.288770
# Chennai Super Kings                    164         100  60.975610
# Kolkata Knight Riders                  178          92  51.685393
# Royal Challengers Bangalore            180          84  46.666667
#              Kings XI Punjab           176          82  46.590909
# Rajasthan Royals                       147          75  51.020408
# Delhi Daredevils                       161          67  41.614907
# Sunrisers Hyderabad                    108          58  53.703704
# Deccan Chargers                         75          29  38.666667
# Gujarat Lions                           30          13  43.333333
# Pune Warriors                           46          12  26.086957
# Rising Pune Supergiant                  16          10  62.500000
# Delhi Capitals                          16          10  62.500000
# ...

# %%
df
# Out:
#         id  season           city        date                        team1  \
# 0        1    2017      Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1        2    2017           Pune  2017-04-06               Mumbai Indians
# 2        3    2017         Rajkot  2017-04-07                Gujarat Lions
# 3        4    2017         Indore  2017-04-08       Rising Pune Supergiant
# 4        5    2017      Bangalore  2017-04-08  Royal Challengers Bangalore
# ..     ...     ...            ...         ...                          ...
# 751  11347    2019         Mumbai    05/05/19        Kolkata Knight Riders
# 752  11412    2019        Chennai    07/05/19          Chennai Super Kings
# 753  11413    2019  Visakhapatnam    08/05/19          Sunrisers Hyderabad
# 754  11414    2019  Visakhapatnam    10/05/19               Delhi Capitals
# 755  11415    2019      Hyderabad    12/05/19               Mumbai Indians
#
# ...

# %%
decision=df.groupby(['toss_winner','toss_decision']).size().unstack()
decision
# Out:
# toss_decision                 bat  field
# toss_winner
# Chennai Super Kings          48.0   41.0
# Deccan Chargers              24.0   19.0
# Delhi Capitals                2.0    8.0
# Delhi Daredevils             29.0   51.0
# Gujarat Lions                 1.0   14.0
# Kings XI Punjab              26.0   55.0
# Kochi Tuskers Kerala          3.0    5.0
# Kolkata Knight Riders        30.0   62.0
# Mumbai Indians               44.0   54.0
# Pune Warriors                11.0    9.0
# Rajasthan Royals             32.0   48.0
# Rising Pune Supergiant        NaN    6.0
# Rising Pune Supergiants       3.0    4.0
# Royal Challengers Bangalore  20.0   61.0
# Sunrisers Hyderabad          20.0   26.0

# %%
df.describe()
# Out:
#                  id       season  dl_applied  win_by_runs  win_by_wickets
# count    756.000000   756.000000  756.000000   756.000000      756.000000
# mean    1792.178571  2013.444444    0.025132    13.283069        3.350529
# std     3464.478148     3.366895    0.156630    23.471144        3.387963
# min        1.000000  2008.000000    0.000000     0.000000        0.000000
# 25%      189.750000  2011.000000    0.000000     0.000000        0.000000
# 50%      378.500000  2013.000000    0.000000     0.000000        4.000000
# 75%      567.250000  2016.000000    0.000000    19.000000        6.000000
# max    11415.000000  2019.000000    1.000000   146.000000       10.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 756 entries, 0 to 755
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               756 non-null    int64
#  1   season           756 non-null    int64
#  2   city             749 non-null    object
#  3   date             756 non-null    object
#  4   team1            756 non-null    object
#  5   team2            756 non-null    object
#  6   toss_winner      756 non-null    object
#  7   toss_decision    756 non-null    object
#  8   result           756 non-null    object
#  9   dl_applied       756 non-null    int64
#  10  winner           752 non-null    object
#  11  win_by_runs      756 non-null    int64
#  12  win_by_wickets   756 non-null    int64
#  13  player_of_match  752 non-null    object
#  14  venue            756 non-null    object
#  15  umpire1          754 non-null    object
#  16  umpire2          754 non-null    object
# ...
